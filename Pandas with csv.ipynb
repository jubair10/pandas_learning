# %%
import pandas as pd

# %%
data = {
    "Name": ["John", "Alice", "Bob"],
    "Age": [30, 25, 35],
    "City": ["New York", "Los Angeles", "Chicago"],
}

df = pd.DataFrame(data)
# print(df)

# Writing
# df.to_csv("Resources/data.csv",index=False)
import time

# time.sleep(3)

# df.to_csv("Resources/data.csv")

# %%
csv_4 = pd.read_csv("Resources\\big_data.csv", dtype={"Price":"float"} )
# print(csv_4.columns)
csv_4.head(5)
# Out:
#                                              Company                Name  \
# 0   Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Barry French
# 2    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl        Barry French
# 3                                               R380       Clay Rozendal
# 4                           Holmes HEPA Air Purifier      Carlos Soltero
#
#    Price  Quantity  Demand  Interest  Ratings                           Niche  \
# 0    3.0   -213.25   38.94     35.00  Nunavut          Storage & Organization
# 1  293.0    457.81  208.16     68.02  Nunavut                      Appliances
# 2  293.0     46.71    8.69      2.99  Nunavut  Binders and Binder Accessories
# 3  483.0   1198.97  195.99      3.99  Nunavut    Telephones and Communication
# 4  515.0     30.94   21.78      5.94  Nunavut                      Appliances
#
#    Stock
# 0   0.80
# 1   0.58
# 2   0.39
# 3   0.58
# ...
